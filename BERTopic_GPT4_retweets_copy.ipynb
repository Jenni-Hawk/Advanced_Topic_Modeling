# %% [markdown]
# # **BERTopic Modeling**
# - Implements GPT4 for topic labeling
# - Creates topic batches for human testing

# %% [markdown]
# # Imports

# %%
import pandas as pd

# %%
import random

# %%
from bertopic import BERTopic
# Out:
# /opt/anaconda3/envs/bertopic/lib/python3.11/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /opt/anaconda3/envs/bertopic/lib/python3.11/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /opt/anaconda3/envs/bertopic/lib/python3.11/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /opt/anaconda3/envs/bertopic/lib/python3.11/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %% [markdown]
# # Data

# %%
tweets = pd.read_csv('/Users/jennihawk/Documents/Data Science Projects/Project_NLP/TweetBatch3.csv')

# %%
tweets.head()
# Out:
#                                                 text
# 0  @ReallyAmerican1 #Roevember and\n#ForThePeople...  \
# 1  RT @sandibachom: IS THIS THING ON???!!This is ...
# 2  RT @sandibachom: IS THIS THING ON???!!This is ...
# 3  RT @tleehumphrey: Today is the beginning of th...
# 4  RT @AdamKinzinger: Mitch McConnell.\nKevin McC...
#
#                                              cleaned
# 0   roevember and forthepeople and votebluein2022...
# 1  rt is this thing on this is pathetic acting se...
# 2  rt is this thing on this is pathetic acting se...
# 3  rt today is the beginning of the inquiry into ...
# 4  rt mitch mcconnell kevin mccarthy they both kn...

# %%
tweets.drop(['cleaned'], axis=1, inplace=True)

# %%
tweets.head()
# Out:
#                                                 text
# 0  @ReallyAmerican1 #Roevember and\n#ForThePeople...
# 1  RT @sandibachom: IS THIS THING ON???!!This is ...
# 2  RT @sandibachom: IS THIS THING ON???!!This is ...
# 3  RT @tleehumphrey: Today is the beginning of th...
# 4  RT @AdamKinzinger: Mitch McConnell.\nKevin McC...

# %%
tweets.shape
# Out:
# (34993, 1)

# %%
#turn tweet column into a list of strings
tweet_list = tweets["text"].tolist()

# %% [markdown]
# # **Topic Modeling**

# %% [markdown]
# ## OpenAI

# %%
from umap import UMAP
from sentence_transformers import SentenceTransformer

# %%
#installed with conda forge https://anaconda.org/conda-forge/openai
import openai

# %%
from bertopic.representation import OpenAI

# %%
# include random state to replicate results / prevents stochastic behavior
umap_model = UMAP(n_neighbors=15, n_components=5,
                  min_dist=0.0, metric='cosine', random_state=42)

# %%
# Fine-tune topic representations with GPT
# https://github.com/theskumar/python-dotenv
openai.api_key = "secret"
representation_model = OpenAI(model="gpt-4", chat=True)

# %%
openai_model = BERTopic(language="english", calculate_probabilities=True, verbose=False, umap_model = umap_model,representation_model=representation_model).fit(tweet_list)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %% [markdown]
# ## Extracting Topics - Most Frequent Topics

# %%
openai_topic_info = openai_model.get_topic_info()

# %%
pd.set_option('display.max_colwidth', None)

# %%
openai_topic_info.head(20)
# Out:
#     Topic  Count
# 0      -1   2695  \
# 1       0   6006
# 2       1   1368
# 3       2   1176
# 4       3   1117
# 5       4   1106
# 6       5   1060
# 7       6    949
# 8       7    712
# 9       8    629
# 10      9    553
# 11     10    466
# 12     11    456
# 13     12    439
# 14     13    438
# 15     14    261
# 16     15    239
# 17     16    229
# 18     17    229
# 19     18    222
#
#                                                                       Name
# 0         -1_January 6th Committee Hearings and Alleged Trump Riot Coverup  \
# 1     0_Reactions of Mitch McConnell and Kevin McCarthy to Trump's Actions
# 2                                           1_Trump's Alleged Coup Attempt
# 3                                2_Unanimous vote to subpoena Donald Trump
# 4                               3_Democracy, Violence and Love for Country
# 5   4_Acting Defense Sec Chris Miller's Authority to Deploy National Guard
# 6                                     5_Trump's Role in January 6th Attack
# 7                       6_Trump's Rejection and Attempt to Break Democracy
# 8                    7_January 6th Committee Hearings & Trump Coup Attempt
# 9               8_Law Enforcement's Inaction on White Nationalist Warnings
# 10                               9_Reaction to January6thCommitteeHearings
# 11                     10_Democracy, Violence, and Mark Hamill's Viewpoint
# 12                            11_Trump's Afraidness and Testimony Reaction
# 13                                    12_FBI Operation and Security Denial
# 14                    13_Appreciation for January 6th Committee Leadership
# 15                          14_Donald Trump's Election Results Controversy
# 16                    15_Pelosi's composure at January6thCommitteeHearings
# 17        16_Ron4California's January 6th Committee Hearings Notifications
# 18                                 17_Trump's Fear and Testimony Challenge
# 19                           18_Dominion Lawsuits and Mar-a-Lago Ownership
#
#                                                             Representation
# 0          [January 6th Committee Hearings and Alleged Trump Riot Coverup]  \
# 1     [Reactions of Mitch McConnell and Kevin McCarthy to Trump's Actions]
# 2                                           [Trump's Alleged Coup Attempt]
# 3                                [Unanimous vote to subpoena Donald Trump]
# 4                               [Democracy, Violence and Love for Country]
# 5   [Acting Defense Sec Chris Miller's Authority to Deploy National Guard]
# 6                                     [Trump's Role in January 6th Attack]
# 7                       [Trump's Rejection and Attempt to Break Democracy]
# 8                    [January 6th Committee Hearings & Trump Coup Attempt]
# 9               [Law Enforcement's Inaction on White Nationalist Warnings]
# 10                               [Reaction to January6thCommitteeHearings]
# 11                      [Democracy, Violence, and Mark Hamill's Viewpoint]
# 12                             [Trump's Afraidness and Testimony Reaction]
# 13                                     [FBI Operation and Security Denial]
# 14                     [Appreciation for January 6th Committee Leadership]
# 15                           [Donald Trump's Election Results Controversy]
# 16                     [Pelosi's composure at January6thCommitteeHearings]
# 17         [Ron4California's January 6th Committee Hearings Notifications]
# 18                                  [Trump's Fear and Testimony Challenge]
# 19                            [Dominion Lawsuits and Mar-a-Lago Ownership]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Representative_Docs
# 0   [RT @StandForBetter: The Secret Service clearly has been involved in a coverup of the Trump riot at The Capitol.\n\n#TrumpsCoupPlaybook\n#Janua…, RT @StandForBetter: The Secret Service clearly has been involved in a coverup of the Trump riot at The Capitol.\n\n#TrumpsCoupPlaybook\n#Janua…, How does it feel to know that YOUR PRESIDENT FAILED YOU ON JAN. 6th… “ I’ll be there with you “ \n\nNow, Trump has to appear before Congress.\n#January6thCommitteeHearings]
# 1                            [RT @AdamKinzinger: Mitch McConnell.\nKevin McCarthy.\nThey both knew Trump was responsible. \nThey both called him out.\nThey both backed down.…, RT @AdamKinzinger: Mitch McConnell.\nKevin McCarthy.\nThey both knew Trump was responsible. \nThey both called him out.\nThey both backed down.…, RT @AdamKinzinger: Mitch McConnell.\nKevin McCarthy.\nThey both knew Trump was responsible. \nThey both called him out.\nThey both backed down.…]
# 2                                  [RT @StandForBetter: 📺 NEW Video:\n\nTrump Lost, yet he decided to hatch a coup with the help of Mark Meadows, Roger Stone, Rudy Giuliani, and…, RT @StandForBetter: 📺 NEW Video:\n\nTrump Lost, yet he decided to hatch a coup with the help of Mark Meadows, Roger Stone, Rudy Giuliani, and…, RT @StandForBetter: 📺 NEW Video:\n\nTrump Lost, yet he decided to hatch a coup with the help of Mark Meadows, Roger Stone, Rudy Giuliani, and…]
# 3                               [RT @AdamKinzinger: We just voted unanimously to subpoena Donald Trump to testify UNDER OATH.\nDemocracy demands it.\nHistory deserves it.\n#Ja…, RT @AdamKinzinger: We just voted unanimously to subpoena Donald Trump to testify UNDER OATH.\nDemocracy demands it.\nHistory deserves it.\n#Ja…, RT @AdamKinzinger: We just voted unanimously to subpoena Donald Trump to testify UNDER OATH.\nDemocracy demands it.\nHistory deserves it.\n#Ja…]
# 4                                        [RT @Resist_MAGA_GOP: Mark Hamill is correct. You can love this country without creating violence by overthrowing democracy. #January6thComm…, RT @Resist_MAGA_GOP: Mark Hamill is correct. You can love this country without creating violence by overthrowing democracy. #January6thComm…, RT @Resist_MAGA_GOP: Mark Hamill is correct. You can love this country without creating violence by overthrowing democracy. #January6thComm…]
# 5                                           [RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…, RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…, RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…]
# 6                               [RT @AdamKinzinger: Trump is the author of the January 6th attack. \nTrump summoned the rioters.\nTrump goaded on their violence.\nTrump excuse…, RT @AdamKinzinger: Trump is the author of the January 6th attack. \nTrump summoned the rioters.\nTrump goaded on their violence.\nTrump excuse…, RT @AdamKinzinger: Trump is the author of the January 6th attack. \nTrump summoned the rioters.\nTrump goaded on their violence.\nTrump excuse…]
# 7                                        [RT @AdamKinzinger: When he couldn't accept his loss - his rejection by the American people - Trump tried to break our democracy. He decided…, RT @AdamKinzinger: When he couldn't accept his loss - his rejection by the American people - Trump tried to break our democracy. He decided…, RT @AdamKinzinger: When he couldn't accept his loss - his rejection by the American people - Trump tried to break our democracy. He decided…]
# 8                                                                                                                            [RT @StandForBetter: This says it all.\n\n#TrumpCoupAttempt\n#January6thCommitteeHearings https://t.co/95KjEX8fAF, RT @StandForBetter: This says it all.\n\n#TrumpCoupAttempt\n#January6thCommitteeHearings https://t.co/95KjEX8fAF, RT @StandForBetter: This says it all.\n\n#TrumpCoupAttempt\n#January6thCommitteeHearings https://t.co/95KjEX8fAF]
# 9                                        [RT @chadloder: The reason law enforcement failed to act on the flood of warnings about the plans for a violent, armed white nationalist ins…, RT @chadloder: The reason law enforcement failed to act on the flood of warnings about the plans for a violent, armed white nationalist ins…, RT @chadloder: The reason law enforcement failed to act on the flood of warnings about the plans for a violent, armed white nationalist ins…]
# 10                                                                                                                                                                                                   [RT @libradunn: That shit was heavy. ✌🏽 y'all take care 🖤\n\n#January6thCommitteeHearings, RT @libradunn: That shit was heavy. ✌🏽 y'all take care 🖤\n\n#January6thCommitteeHearings, RT @libradunn: That shit was heavy. ✌🏽 y'all take care 🖤\n\n#January6thCommitteeHearings]
# 11                                       [RT @Resist_MAGA_GOP: Mark Hamill is correct. You can love this country without creating violence by overthrowing democracy. #January6thComm…, RT @Resist_MAGA_GOP: Mark Hamill is correct. You can love this country without creating violence by overthrowing democracy. #January6thComm…, RT @Resist_MAGA_GOP: Mark Hamill is correct. You can love this country without creating violence by overthrowing democracy. #January6thComm…]
# 12                                       [RT @tomiahonen: Hey Trump? What happened? You afraid? She testified for 11 hours under oath. Come on Trump? Get the biggest audience you ev…, RT @tomiahonen: Hey Trump? What happened? You afraid? She testified for 11 hours under oath. Come on Trump? Get the biggest audience you ev…, RT @tomiahonen: Hey Trump? What happened? You afraid? She testified for 11 hours under oath. Come on Trump? Get the biggest audience you ev…]
# 13                                 [RT @fugitivemama: She knew of the FBI operation. She knew about the setup. She knew and still denied extra security. \n\nShe fucking knew. #J…, RT @fugitivemama: She knew of the FBI operation. She knew about the setup. She knew and still denied extra security. \n\nShe fucking knew. #J…, RT @fugitivemama: She knew of the FBI operation. She knew about the setup. She knew and still denied extra security. \n\nShe fucking knew. #J…]
# 14                           [RT @SIfill_: I want to send a special thanks to Chair @BennieGThompson &amp; Vice-Chair @RepLizCheney for their service leading the #January6th…, RT @SIfill_: I want to send a special thanks to Chair @BennieGThompson &amp; Vice-Chair @RepLizCheney for their service leading the #January6th…, RT @SIfill_: I want to send a special thanks to Chair @BennieGThompson &amp; Vice-Chair @RepLizCheney for their service leading the #January6th…]
# 15                                       [RT @votevets: Donald Trump, and everyone around him, knew he was lying about election results. He was then, and STILL is, an ongoing nation…, RT @votevets: Donald Trump, and everyone around him, knew he was lying about election results. He was then, and STILL is, an ongoing nation…, RT @votevets: Donald Trump, and everyone around him, knew he was lying about election results. He was then, and STILL is, an ongoing nation…]
# 16                                                                        [RT @littlemissmarxi: Pelosi knew they were coming for her and held it together like the boss she is. #January6thCommitteeHearings, RT @littlemissmarxi: Pelosi knew they were coming for her and held it together like the boss she is. #January6thCommitteeHearings, RT @littlemissmarxi: Pelosi knew they were coming for her and held it together like the boss she is. #January6thCommitteeHearings]
# 17                                                                                                                                       [RT @Ron4California: Every time the #January6thCommitteeHearings are on, I get more notifications about this., RT @Ron4California: Every time the #January6thCommitteeHearings are on, I get more notifications about this., RT @Ron4California: Every time the #January6thCommitteeHearings are on, I get more notifications about this.]
# 18                                       [RT @tomiahonen: Hey Trump? What happened? You afraid? She testified for 11 hours under oath. Come on Trump? Get the biggest audience you ev…, RT @tomiahonen: Hey Trump? What happened? You afraid? She testified for 11 hours under oath. Come on Trump? Get the biggest audience you ev…, RT @tomiahonen: Hey Trump? What happened? You afraid? She testified for 11 hours under oath. Come on Trump? Get the biggest audience you ev…]
# 19                                                                                                   [RT @joekatz45: Dominion is going to end up owning Mar-a-Lago when the lawsuits are over.\n\n#January6thCommitteeHearings, RT @joekatz45: Dominion is going to end up owning Mar-a-Lago when the lawsuits are over.\n\n#January6thCommitteeHearings, RT @joekatz45: Dominion is going to end up owning Mar-a-Lago when the lawsuits are over.\n\n#January6thCommitteeHearings]

# %%
#openai_topic_info.to_csv('gpt4_frequent_topics_retweets.csv')

# %% [markdown]
# #### OpenAI Get Document Info

# %%
openai_doc_info = openai_model.get_document_info(tweet_list)

# %%
openai_doc_info
# Out:
#                                                                                                                                                                                                                                                                                                Document
# 0      @ReallyAmerican1 #Roevember and\n#ForThePeople and\n#VoteBlueIn2022 and \n#StandWithUkraine️ and\n#PeopleOverPolitics and\n#OathBreakerMAGA and\n#LGBTQHistoryMonth and\n#InflationReductionAct and\n#RepublicanWarOnSeniors and\n#SocialSecurityIsOurMoney and\n#January6thCommitteeHearings...  \
# 1                                                                                                                                                           RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…
# 2                                                                                                                                                           RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…
# 3                                                                                                                                                          RT @tleehumphrey: Today is the beginning of the inquiry into the Trudeau gov’s use of the Emergencies Act against the #FreedomConvoy so wha…
# 4                                                                                                                                                      RT @AdamKinzinger: Mitch McConnell.\nKevin McCarthy.\nThey both knew Trump was responsible. \nThey both called him out.\nThey both backed down.…
# ...                                                                                                                                                                                                                                                                                                 ...
# 34988                                                                                                                                                       RT @Adrian_Fontes: The January 6th committee just concluded its final hearing ahead of the midterms. These brave leaders remind us that we…
# 34989                                                                                                                                                                                                             #January6thCommitteeHearings and everyone running them are 🤡🌎 https://t.co/w3YONp1tdH
# 34990                                                                                                                                                       RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…
# 34991                                                                                                                                              So they are gonna subpoena Trump I am guessing they stop calling him the 45th and just start calling him the 5th 🤣🤣🤣🤣🤣🤣🤣#January6thCommitteeHearings
# 34992                                                                                                                                                      RT @mariashriver: This is a historic day. @RepLizCheney’s words were somber. Regardless of who you voted for in the last election, she is r…
#
#        Topic
# 0         25  \
# 1          4
# 2          4
# 3        104
# 4          0
# ...      ...
# 34988     42
# 34989     16
# 34990      4
# 34991     94
# 34992     72
#
#                                                                               Name
# 0                              25_Political Activism and Advocacy on Social Issues  \
# 1           4_Acting Defense Sec Chris Miller's Authority to Deploy National Guard
# 2           4_Acting Defense Sec Chris Miller's Authority to Deploy National Guard
# 3      104_Inquiry into Trudeau Gov's use of Emergencies Act against FreedomConvoy
# 4             0_Reactions of Mitch McConnell and Kevin McCarthy to Trump's Actions
# ...                                                                            ...
# 34988                                       42_January 6th Committee Final Hearing
# 34989             16_Ron4California's January 6th Committee Hearings Notifications
# 34990       4_Acting Defense Sec Chris Miller's Authority to Deploy National Guard
# 34991                 94_January 6th Committee's Planned Subpoena for Donald Trump
# 34992                            72_Liz Cheney's Historic Day and Her Somber Words
#
#                                                                   Representation
# 0                             [Political Activism and Advocacy on Social Issues]  \
# 1         [Acting Defense Sec Chris Miller's Authority to Deploy National Guard]
# 2         [Acting Defense Sec Chris Miller's Authority to Deploy National Guard]
# 3      [Inquiry into Trudeau Gov's use of Emergencies Act against FreedomConvoy]
# 4           [Reactions of Mitch McConnell and Kevin McCarthy to Trump's Actions]
# ...                                                                          ...
# 34988                                      [January 6th Committee Final Hearing]
# 34989            [Ron4California's January 6th Committee Hearings Notifications]
# 34990     [Acting Defense Sec Chris Miller's Authority to Deploy National Guard]
# 34991                [January 6th Committee's Planned Subpoena for Donald Trump]
# 34992                           [Liz Cheney's Historic Day and Her Somber Words]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Representative_Docs
# 0      [@michael_muscato #Roevember and\n#ForThePeople and\n#VoteBlueIn2022 and \n#StandWithUkraine️ and\n#PeopleOverPolitics and\n#OathBreakerMAGA and\n#LGBTQHistoryMonth and\n#InflationReductionAct and\n#RepublicanWarOnSeniors and\n#SocialSecurityIsOurMoney and\n#January6thCommitteeHearings..., @santiagomayer_ #Roevember and\n#ForThePeople and\n#VoteBlueIn2022 and \n#StandWithUkraine️ and\n#PeopleOverPolitics and\n#OathBreakerMAGA and\n#LGBTQHistoryMonth and\n#InflationReductionAct and\n#RepublicanWarOnSeniors and\n#SocialSecurityIsOurMoney and\n#January6thCommitteeHearings..., @ashley_ehasz #Roevember and\n#ForThePeople and\n#VoteBlueIn2022 and \n#StandWithUkraine️ and\n#PeopleOverPolitics and\n#OathBreakerMAGA and\n#LGBTQHistoryMonth and\n#InflationReductionAct and\n#RepublicanWarOnSeniors and\n#SocialSecurityIsOurMoney and\n#January6thCommitteeHearings...]  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…, RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…, RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…, RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…, RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                              [RT @tleehumphrey: Today is the beginning of the inquiry into the Trudeau gov’s use of the Emergencies Act against the #FreedomConvoy so wha…, RT @tleehumphrey: Today is the beginning of the inquiry into the Trudeau gov’s use of the Emergencies Act against the #FreedomConvoy so wha…, RT @tleehumphrey: Today is the beginning of the inquiry into the Trudeau gov’s use of the Emergencies Act against the #FreedomConvoy so wha…]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                  [RT @AdamKinzinger: Mitch McConnell.\nKevin McCarthy.\nThey both knew Trump was responsible. \nThey both called him out.\nThey both backed down.…, RT @AdamKinzinger: Mitch McConnell.\nKevin McCarthy.\nThey both knew Trump was responsible. \nThey both called him out.\nThey both backed down.…, RT @AdamKinzinger: Mitch McConnell.\nKevin McCarthy.\nThey both knew Trump was responsible. \nThey both called him out.\nThey both backed down.…]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 34988                                                                                                                                                                                                                                                                                                                                                                                                                                                             [RT @Adrian_Fontes: The January 6th committee just concluded its final hearing ahead of the midterms. These brave leaders remind us that we…, RT @Adrian_Fontes: The January 6th committee just concluded its final hearing ahead of the midterms. These brave leaders remind us that we…, RT @Adrian_Fontes: The January 6th committee just concluded its final hearing ahead of the midterms. These brave leaders remind us that we…]
# 34989                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [RT @Ron4California: Every time the #January6thCommitteeHearings are on, I get more notifications about this., RT @Ron4California: Every time the #January6thCommitteeHearings are on, I get more notifications about this., RT @Ron4California: Every time the #January6thCommitteeHearings are on, I get more notifications about this.]
# 34990                                                                                                                                                                                                                                                                                                                                                                                                                                                             [RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…, RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…, RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…]
# 34991                                                                                                                                                                                                                                                                                                                                                                                                                                                          [RT @CyrusMMcQueen: It appears the January 6th Committee is prepared to subpoena Donald Trump… Until of course one of his paid troglodytes i…, RT @CyrusMMcQueen: It appears the January 6th Committee is prepared to subpoena Donald Trump… Until of course one of his paid troglodytes i…, RT @CyrusMMcQueen: It appears the January 6th Committee is prepared to subpoena Donald Trump… Until of course one of his paid troglodytes i…]
# 34992                                                                                                                                                                                                                                                                                                                                                                                                                                                          [RT @mariashriver: This is a historic day. @RepLizCheney’s words were somber. Regardless of who you voted for in the last election, she is r…, RT @mariashriver: This is a historic day. @RepLizCheney’s words were somber. Regardless of who you voted for in the last election, she is r…, RT @mariashriver: This is a historic day. @RepLizCheney’s words were somber. Regardless of who you voted for in the last election, she is r…]
#
#                                                                    Top_n_words
# 0                             Political Activism and Advocacy on Social Issues  \
# 1         Acting Defense Sec Chris Miller's Authority to Deploy National Guard
# 2         Acting Defense Sec Chris Miller's Authority to Deploy National Guard
# 3      Inquiry into Trudeau Gov's use of Emergencies Act against FreedomConvoy
# 4           Reactions of Mitch McConnell and Kevin McCarthy to Trump's Actions
# ...                                                                        ...
# 34988                                      January 6th Committee Final Hearing
# 34989            Ron4California's January 6th Committee Hearings Notifications
# 34990     Acting Defense Sec Chris Miller's Authority to Deploy National Guard
# 34991                January 6th Committee's Planned Subpoena for Donald Trump
# 34992                           Liz Cheney's Historic Day and Her Somber Words
#
#        Probability  Representative_document
# 0         0.233988                    False
# 1         1.000000                     True
# 2         0.586859                     True
# 3         1.000000                     True
# 4         0.201421                     True
# ...            ...                      ...
# 34988     0.138174                     True
# 34989     0.029946                    False
# 34990     0.162626                     True
# 34991     0.105250                    False
# 34992     0.086228                     True
#
# [34993 rows x 8 columns]

# %%
openai_doc_info.to_csv('gpt4_all_content_retweets.csv')

# %% [markdown]
# # Create Intruder Batches For Human Coherence Testing

# %% [markdown]
# ### BERTopic Intruder Batches

# %%
#dataframe that strips unecessary info when running through batch function
openai_doc_info2 = openai_doc_info.copy()

# %%
openai_doc_info2.drop(['Representation', 'Representative_Docs', 'Top_n_words', 'Probability', 'Representative_document'], axis=1, inplace=True)

# %%
openai_doc_info2.head()
# Out:
#                                                                                                                                                                                                                                                                                            Document
# 0  @ReallyAmerican1 #Roevember and\n#ForThePeople and\n#VoteBlueIn2022 and \n#StandWithUkraine️ and\n#PeopleOverPolitics and\n#OathBreakerMAGA and\n#LGBTQHistoryMonth and\n#InflationReductionAct and\n#RepublicanWarOnSeniors and\n#SocialSecurityIsOurMoney and\n#January6thCommitteeHearings...  \
# 1                                                                                                                                                       RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…
# 2                                                                                                                                                       RT @sandibachom: IS THIS THING ON???!!This is pathetic. ACTING Sec of Defense Chris Miller was the ONLY person who can deploy the national…
# 3                                                                                                                                                      RT @tleehumphrey: Today is the beginning of the inquiry into the Trudeau gov’s use of the Emergencies Act against the #FreedomConvoy so wha…
# 4                                                                                                                                                  RT @AdamKinzinger: Mitch McConnell.\nKevin McCarthy.\nThey both knew Trump was responsible. \nThey both called him out.\nThey both backed down.…
#
#    Topic
# 0     25  \
# 1      4
# 2      4
# 3    104
# 4      0
#
#                                                                           Name
# 0                          25_Political Activism and Advocacy on Social Issues
# 1       4_Acting Defense Sec Chris Miller's Authority to Deploy National Guard
# 2       4_Acting Defense Sec Chris Miller's Authority to Deploy National Guard
# 3  104_Inquiry into Trudeau Gov's use of Emergencies Act against FreedomConvoy
# 4         0_Reactions of Mitch McConnell and Kevin McCarthy to Trump's Actions

# %%
def create_batch(df, main_topic, specific_topic):
    # Get unique topics
    topics = df['Name'].unique()

    # Check if the main_topic is in the topics
    if main_topic not in topics:
        raise ValueError(f"Main topic '{main_topic}' not found in the DataFrame.")
    
    batch_topic_df = df[df['Name'] == main_topic]
    batch = batch_topic_df.sample(n=4).to_dict('records')
    
    # Mark these documents as not intruders
    for doc in batch:
        doc['intruder'] = 0

    # Select intruder documents from another topic
    intruder_df = df[df['Name'] == specific_topic].sample(1)

    # Converting ths sampled 'intruder_df' into a list of dicts and marking as intruders
    intruders = intruder_df.to_dict('records')  
    for intruder in intruders:
        intruder['intruder'] = 1

    # Add the intruder document to the batch
    batch.extend(intruders)
    
    # Shuffle the batch to randomly position the intruder
    random.shuffle(batch)

    return batch

# %%
#pd.set_option('display.max_colwidth', None)

# %%
# #creates list of dicts
# topic0_batch1 = create_batch(openai_doc_info2, "0_Politicians' Response to Trump's Responsibility", "1_Trump's coup attempt with the help of Giuliani, Meadows, Stone, and others")
# #creates dataframe from list of dicts
# topic0_batch1 = pd.DataFrame.from_records(topic0_batch1)

# %%
# #creates list of dicts
# topic0_batch2 = create_batch(openai_doc_info2, "0_Politicians' Response to Trump's Responsibility", "2_Testifying Donald Trump under oath")
# #creates dataframe from list of dicts
# topic0_batch2 = pd.DataFrame.from_records(topic0_batch2)

# %%
# #creates list of dicts
# topic0_batch3 = create_batch(openai_doc_info2, "0_Politicians' Response to Trump's Responsibility", "3_Mark Hamill's views on loving the country without creating violence by overthrowing democracy #January6thComm")
# #creates dataframe from list of dicts
# topic0_batch3 = pd.DataFrame.from_records(topic0_batch3)

# %%
# #creates list of dicts
# topic0_batch4 = create_batch(openai_doc_info2, "0_Politicians' Response to Trump's Responsibility", "4_Deployment of Acting Sec of Defense Chris Miller by National Guard denied")
# #creates dataframe from list of dicts
# topic0_batch4 = pd.DataFrame.from_records(topic0_batch4)

# %%
# #creates list of dicts
# topic0_batch5 = create_batch(openai_doc_info2, "0_Politicians' Response to Trump's Responsibility", "5_Trump's Involvement in the January 6th Attack")
# #creates dataframe from list of dicts
# topic0_batch5 = pd.DataFrame.from_records(topic0_batch5)

# %%
#topic0_batch5

# %%
# topic1_batch1 = create_batch(openai_doc_info2, "1_Trump's coup attempt with the help of Giuliani, Meadows, Stone, and others", "0_Politicians' Response to Trump's Responsibility")
# #creates dataframe from list of dicts
# topic1_batch1 = pd.DataFrame.from_records(topic1_batch1)

# %%
# topic1_batch2 = create_batch(openai_doc_info2, "1_Trump's coup attempt with the help of Giuliani, Meadows, Stone, and others", "2_Testifying Donald Trump under oath")
# #creates dataframe from list of dicts
# topic1_batch2 = pd.DataFrame.from_records(topic1_batch2)

# %%
# topic1_batch3 = create_batch(openai_doc_info2, "1_Trump's coup attempt with the help of Giuliani, Meadows, Stone, and others", "3_Mark Hamill's views on loving the country without creating violence by overthrowing democracy #January6thComm")
# #creates dataframe from list of dicts
# topic1_batch3 = pd.DataFrame.from_records(topic1_batch3)

# %%
# topic1_batch4 = create_batch(openai_doc_info2, "1_Trump's coup attempt with the help of Giuliani, Meadows, Stone, and others", "5_Trump's Involvement in the January 6th Attack")
# #creates dataframe from list of dicts
# topic1_batch4 = pd.DataFrame.from_records(topic1_batch4)

# %%
# topic1_batch5 = create_batch(openai_doc_info2, "1_Trump's coup attempt with the help of Giuliani, Meadows, Stone, and others", "4_Deployment of Acting Sec of Defense Chris Miller by National Guard denied")
# #creates dataframe from list of dicts
# topic1_batch5 = pd.DataFrame.from_records(topic1_batch5)

# %%
# topic2_batch1 = create_batch(openai_doc_info2, "2_Testifying Donald Trump under oath", "1_Trump's coup attempt with the help of Giuliani, Meadows, Stone, and others")
# #creates dataframe from list of dicts
# topic2_batch1 = pd.DataFrame.from_records(topic2_batch1)

# %%
# topic2_batch2 = create_batch(openai_doc_info2, "2_Testifying Donald Trump under oath", "0_Politicians' Response to Trump's Responsibility")
# #creates dataframe from list of dicts
# topic2_batch2 = pd.DataFrame.from_records(topic2_batch2)

# %%
# topic2_batch3 = create_batch(openai_doc_info2, "2_Testifying Donald Trump under oath", "3_Mark Hamill's views on loving the country without creating violence by overthrowing democracy #January6thComm")
# #creates dataframe from list of dicts
# topic2_batch3 = pd.DataFrame.from_records(topic2_batch3)

# %%
# topic2_batch4 = create_batch(openai_doc_info2, "2_Testifying Donald Trump under oath", "4_Deployment of Acting Sec of Defense Chris Miller by National Guard denied")
# #creates dataframe from list of dicts
# topic2_batch4 = pd.DataFrame.from_records(topic2_batch4)

# %%
# topic2_batch5 = create_batch(openai_doc_info2, "2_Testifying Donald Trump under oath", "5_Trump's Involvement in the January 6th Attack")
# #creates dataframe from list of dicts
# topic2_batch5 = pd.DataFrame.from_records(topic2_batch5)

# %%
# topic3_batch1 = create_batch(openai_doc_info2, "3_Mark Hamill's views on loving the country without creating violence by overthrowing democracy #January6thComm", "0_Politicians' Response to Trump's Responsibility")
# #creates dataframe from list of dicts
# topic3_batch1 = pd.DataFrame.from_records(topic3_batch1)

# %%
# topic3_batch2 = create_batch(openai_doc_info2, "3_Mark Hamill's views on loving the country without creating violence by overthrowing democracy #January6thComm", "1_Trump's coup attempt with the help of Giuliani, Meadows, Stone, and others")
# #creates dataframe from list of dicts
# topic3_batch2 = pd.DataFrame.from_records(topic3_batch2)

# %%
# topic3_batch3 = create_batch(openai_doc_info2, "3_Mark Hamill's views on loving the country without creating violence by overthrowing democracy #January6thComm", '2_Testifying Donald Trump under oath')
# #creates dataframe from list of dicts
# topic3_batch3 = pd.DataFrame.from_records(topic3_batch3)

# %%
# topic3_batch4 = create_batch(openai_doc_info2, "3_Mark Hamill's views on loving the country without creating violence by overthrowing democracy #January6thComm", "4_Deployment of Acting Sec of Defense Chris Miller by National Guard denied")
# #creates dataframe from list of dicts
# topic3_batch4 = pd.DataFrame.from_records(topic3_batch4)

# %%
# topic3_batch5 = create_batch(openai_doc_info2, "3_Mark Hamill's views on loving the country without creating violence by overthrowing democracy #January6thComm", "5_Trump's Involvement in the January 6th Attack")
# #creates dataframe from list of dicts
# topic3_batch5 = pd.DataFrame.from_records(topic3_batch5)

# %%
# topic4_batch1 = create_batch(openai_doc_info2, "4_Deployment of Acting Sec of Defense Chris Miller by National Guard denied", "0_Politicians' Response to Trump's Responsibility")
# #creates dataframe from list of dicts
# topic4_batch1 = pd.DataFrame.from_records(topic4_batch1)

# %%
# topic4_batch2 = create_batch(openai_doc_info2, "4_Deployment of Acting Sec of Defense Chris Miller by National Guard denied", "1_Trump's coup attempt with the help of Giuliani, Meadows, Stone, and others")
# #creates dataframe from list of dicts
# topic4_batch2 = pd.DataFrame.from_records(topic4_batch2)

# %%
# topic4_batch3 = create_batch(openai_doc_info2, "4_Deployment of Acting Sec of Defense Chris Miller by National Guard denied", "2_Testifying Donald Trump under oath")
# #creates dataframe from list of dicts
# topic4_batch3 = pd.DataFrame.from_records(topic4_batch3)

# %%
# topic4_batch4 = create_batch(openai_doc_info2, "4_Deployment of Acting Sec of Defense Chris Miller by National Guard denied", "3_Mark Hamill's views on loving the country without creating violence by overthrowing democracy #January6thComm")
# #creates dataframe from list of dicts
# topic4_batch4 = pd.DataFrame.from_records(topic4_batch4)

# %%
# topic4_batch5 = create_batch(openai_doc_info2, "4_Deployment of Acting Sec of Defense Chris Miller by National Guard denied", "5_Trump's Involvement in the January 6th Attack")
# #creates dataframe from list of dicts
# topic4_batch5 = pd.DataFrame.from_records(topic4_batch5)

# %%
# topic5_batch1 = create_batch(openai_doc_info2, "5_Trump's Involvement in the January 6th Attack", "0_Politicians' Response to Trump's Responsibility")
# #creates dataframe from list of dicts
# topic5_batch1 = pd.DataFrame.from_records(topic5_batch1)

# %%
# topic5_batch2 = create_batch(openai_doc_info2, "5_Trump's Involvement in the January 6th Attack", "1_Trump's coup attempt with the help of Giuliani, Meadows, Stone, and others")
# #creates dataframe from list of dicts
# topic5_batch2 = pd.DataFrame.from_records(topic5_batch2)

# %%
# topic5_batch3 = create_batch(openai_doc_info2, "5_Trump's Involvement in the January 6th Attack", "2_Testifying Donald Trump under oath")
# #creates dataframe from list of dicts
# topic5_batch3 = pd.DataFrame.from_records(topic5_batch3)

# %%
# topic5_batch4 = create_batch(openai_doc_info2, "5_Trump's Involvement in the January 6th Attack", "3_Mark Hamill's views on loving the country without creating violence by overthrowing democracy #January6thComm")
# #creates dataframe from list of dicts
# topic5_batch4 = pd.DataFrame.from_records(topic5_batch4)

# %%
# topic5_batch5 = create_batch(openai_doc_info2, "5_Trump's Involvement in the January 6th Attack", "4_Deployment of Acting Sec of Defense Chris Miller by National Guard denied")
# #creates dataframe from list of dicts
# topic5_batch5 = pd.DataFrame.from_records(topic5_batch5)

# %% [markdown]
# #### All Batches into Dataframe

# %%
# frames = [topic0_batch1,
# topic0_batch2,
# topic0_batch3,
# topic0_batch4,
# topic0_batch5,
# topic1_batch1,
# topic1_batch2,
# topic1_batch3,
# topic1_batch4,
# topic1_batch5,
# topic2_batch1,
# topic2_batch2,
# topic2_batch3,
# topic2_batch4,
# topic2_batch5,
# topic3_batch1,
# topic3_batch2,
# topic3_batch3,
# topic3_batch4,
# topic3_batch5,
# topic4_batch1,
# topic4_batch2,
# topic4_batch3,
# topic4_batch4,
# topic4_batch5,
# topic5_batch1,
# topic5_batch2,
# topic5_batch3,
# topic5_batch4,
# topic5_batch5
# ]

# %%
#result = pd.concat(frames)

# %%
# reset index
#result.reset_index(drop=True, inplace=True)

# %%
#result.head(20)

# %%
# #create column with intruder index
# result['intruder_index'] = None

# %%
# # Assign the index to the new column where column 'B' is True
# result.loc[result['intruder'] == True, 'intruder_index'] = result.index[result['intruder'] == True]

# %%
#result

# %%
#result.to_csv('open_ai_bertopic_with_dupes.csv')
